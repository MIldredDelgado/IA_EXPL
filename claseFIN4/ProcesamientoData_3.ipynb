# %% [markdown]
# #

# %% [markdown]
# # EDA: Analísis exploratorio de los datos

# %% [markdown]
# ## 1. Representación data con pandas

# %% [markdown]
# ### 1.1. Importar libreria relevantes
#
# 1.   Elemento de lista
# 2.   Elemento de lista

# %%
import pandas as pd
import numpy as np

#visualizacion
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

#conectar con drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1.2. Abrir data

# %%
# leer un archivo csv, ya descargado, e imprimir la cabeza (primero 5 elementos)

# %%
df = pd.read_csv('/content/drive/MyDrive/bootcamp_ia_2026-1/ds_salaries.csv')

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %% [markdown]
# ### 1.3. Exploración, análisis descripttivo

# %%
# ver encabezado de la data (las primeras 5 filas)
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
# mostrar las ultimas 5 lineas, filas o registros
df.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
# 604         604       2022               SE              FT   Data Analyst
# 605         605       2022               SE              FT   Data Analyst
# 606         606       2022               MI              FT   AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# ...

# %%
# para describir la data, muestra un  resumen estadístico del dataset
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
# muestra una lista con todas las columnas que tiene el data frame
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
#hacer consultas especificas del dataframe

df[df.salary_in_usd > 250000]
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 1             1       2020               SE              FT
# 25           25       2020               EX              FT
# 33           33       2020               MI              FT
# 63           63       2020               SE              FT
# 78           78       2021               MI              CT
# 93           93       2021               SE              FT
# 97           97       2021               MI              FT
# 157         157       2021               MI              FT
# 225         225       2021               EX              CT
# 231         231       2021               SE              FT
# 252         252       2021               EX              FT
# 416         416       2022               SE              FT
# 482         482       2022               EX              FT
# 519         519       2022               SE              FT
# 523         523       2022               SE              FT
# ...

# %%
df[df.salary_in_usd > 250000].describe() #la descripción  salarios mayores a 250.000
# Out:
#        Unnamed: 0    work_year         salary  salary_in_usd  remote_ratio
# count    16.00000    16.000000      16.000000      16.000000     16.000000
# mean    233.06250  2021.062500  360837.500000  360837.500000     78.125000
# std     197.70364     0.771902   97733.221066   97733.221066     40.697051
# min       1.00000  2020.000000  256000.000000  256000.000000      0.000000
# 25%      74.25000  2020.750000  269100.000000  269100.000000     87.500000
# 50%     191.00000  2021.000000  352500.000000  352500.000000    100.000000
# 75%     432.50000  2022.000000  417750.000000  417750.000000    100.000000
# max     534.00000  2022.000000  600000.000000  600000.000000    100.000000

# %%
#los valores de cierto campo determinado
df.job_title
# Out:
# 0                  Data Scientist
# 1      Machine Learning Scientist
# 2               Big Data Engineer
# 3            Product Data Analyst
# 4       Machine Learning Engineer
#                   ...
# 602                 Data Engineer
# 603                 Data Engineer
# 604                  Data Analyst
# 605                  Data Analyst
# 606                  AI Scientist
# Name: job_title, Length: 607, dtype: object

# %%
# hacer una consulta tipo QUERY
df.query("job_title == 'Data Scientist'") #RECUERDE QUE LA CONSULTA QUERY DEBE SER DENTRO DE UNA CADENA
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0             0       2020               MI              FT  Data Scientist
# 7             7       2020               MI              FT  Data Scientist
# 10           10       2020               EN              FT  Data Scientist
# 11           11       2020               MI              FT  Data Scientist
# 12           12       2020               EN              FT  Data Scientist
# ..          ...        ...              ...             ...             ...
# 592         592       2022               SE              FT  Data Scientist
# 593         593       2022               SE              FT  Data Scientist
# 596         596       2022               SE              FT  Data Scientist
# 598         598       2022               MI              FT  Data Scientist
# 599         599       2022               MI              FT  Data Scientist
#
# ...

# %%
# las filas determinadas
df.iloc[20:40]
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 20          20       2020               MI              FT
# 21          21       2020               MI              FT
# 22          22       2020               SE              FT
# 23          23       2020               MI              FT
# 24          24       2020               MI              FT
# 25          25       2020               EX              FT
# 26          26       2020               EN              FT
# 27          27       2020               SE              FT
# 28          28       2020               EN              CT
# 29          29       2020               SE              FT
# 30          30       2020               MI              FT
# 31          31       2020               EN              FT
# 32          32       2020               SE              FT
# 33          33       2020               MI              FT
# 34          34       2020               MI              FT
# ...

# %%
#columnas especificas de una dataframe
df[["job_title", "salary"]]
# Out:
#                       job_title  salary
# 0                Data Scientist   70000
# 1    Machine Learning Scientist  260000
# 2             Big Data Engineer   85000
# 3          Product Data Analyst   20000
# 4     Machine Learning Engineer  150000
# ..                          ...     ...
# 602               Data Engineer  154000
# 603               Data Engineer  126000
# 604                Data Analyst  129000
# 605                Data Analyst  150000
# 606                AI Scientist  200000
#
# [607 rows x 2 columns]

# %%
'''otra forma es con la estructura iloc, pero no dando nombres sino posiciones
recordar que la primera posicion es filas las demÁs columnas)'''

df.iloc[:, [2,4,5]]
# Out:
#     experience_level                   job_title  salary
# 0                 MI              Data Scientist   70000
# 1                 SE  Machine Learning Scientist  260000
# 2                 SE           Big Data Engineer   85000
# 3                 MI        Product Data Analyst   20000
# 4                 SE   Machine Learning Engineer  150000
# ..               ...                         ...     ...
# 602               SE               Data Engineer  154000
# 603               SE               Data Engineer  126000
# 604               SE                Data Analyst  129000
# 605               SE                Data Analyst  150000
# 606               MI                AI Scientist  200000
#
# [607 rows x 3 columns]

# %%
# columnas determinadas y filas determinadas (estas ultimas son las primeras)
df.iloc[10:40, [2,4,5]]
# Out:
#    experience_level                  job_title   salary
# 10               EN             Data Scientist    45000
# 11               MI             Data Scientist  3000000
# 12               EN             Data Scientist    35000
# 13               MI          Lead Data Analyst    87000
# 14               MI               Data Analyst    85000
# 15               MI               Data Analyst     8000
# 16               EN              Data Engineer  4450000
# 17               SE          Big Data Engineer   100000
# 18               EN    Data Science Consultant   423000
# 19               MI         Lead Data Engineer    56000
# 20               MI  Machine Learning Engineer   299000
# 21               MI       Product Data Analyst   450000
# 22               SE              Data Engineer    42000
# 23               MI            BI Data Analyst    98000
# 24               MI        Lead Data Scientist   115000
# 25               EX   Director of Data Science   325000
# ...

# %%
# las columnas con nombres y no por posicion, desde una a otra
df.loc[:,"experience_level": "job_title"]
# Out:
#     experience_level employment_type                   job_title
# 0                 MI              FT              Data Scientist
# 1                 SE              FT  Machine Learning Scientist
# 2                 SE              FT           Big Data Engineer
# 3                 MI              FT        Product Data Analyst
# 4                 SE              FT   Machine Learning Engineer
# ..               ...             ...                         ...
# 602               SE              FT               Data Engineer
# 603               SE              FT               Data Engineer
# 604               SE              FT                Data Analyst
# 605               SE              FT                Data Analyst
# 606               MI              FT                AI Scientist
#
# [607 rows x 3 columns]

# %%
#otra forma de consultar, parecido al query
df.loc[df["experience_level"]== "MI"]
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 3             3       2020               MI              FT
# 7             7       2020               MI              FT
# 8             8       2020               MI              FT
# 11           11       2020               MI              FT
# ..          ...        ...              ...             ...
# 567         567       2022               MI              FT
# 586         586       2022               MI              FT
# 598         598       2022               MI              FT
# 599         599       2022               MI              FT
# 606         606       2022               MI              FT
#
#                  job_title    salary salary_currency  salary_in_usd  \
# 0           Data Scientist     70000             EUR          79833
# 3     Product Data Analyst     20000             USD          20000
# ...

# %%
# columnas especifica  en una consulta de comparación
df.loc[df["experience_level"]== "MI", ["job_title",	"salary"]]
# Out:
#                  job_title    salary
# 0           Data Scientist     70000
# 3     Product Data Analyst     20000
# 7           Data Scientist  11000000
# 8    Business Data Analyst    135000
# 11          Data Scientist   3000000
# ..                     ...       ...
# 567           Data Analyst     50000
# 586           Data Analyst     35000
# 598         Data Scientist    160000
# 599         Data Scientist    130000
# 606           AI Scientist    200000
#
# [213 rows x 2 columns]

# %%
# ordenar consulta de forma ascendente
df.loc[df["experience_level"]== "MI", ["job_title",	"salary"]].sort_values("salary", ascending=True)
# Out:
#                       job_title    salary
# 185               Data Engineer      4000
# 15                 Data Analyst      8000
# 184  Machine Learning Scientist     12000
# 192           Big Data Engineer     18000
# 208               Data Engineer     20000
# ..                          ...       ...
# 136                 ML Engineer   7000000
# 137                 ML Engineer   8500000
# 7                Data Scientist  11000000
# 102             BI Data Analyst  11000000
# 177              Data Scientist  30400000
#
# [213 rows x 2 columns]

# %%
#cambiar el nombre de una columna
df.rename(columns= {"salary": "salario"})
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salario salary_currency  salary_in_usd  \
# 0                Data Scientist    70000             EUR          79833
# 1    Machine Learning Scientist   260000             USD         260000
# ...

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
# obtener muestras aleatorias
df.sample(frac=0.5) #fragmento deel 50 por ciento de los datos
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 543         543       2022               MI              FT
# 137         137       2021               MI              FT
# 314         314       2022               MI              FT
# 518         518       2022               MI              FT
# 598         598       2022               MI              FT
# ..          ...        ...              ...             ...
# 17           17       2020               SE              FT
# 234         234       2021               MI              FT
# 301         301       2022               SE              FT
# 351         351       2022               SE              FT
# 54           54       2020               SE              FL
#
#                     job_title   salary salary_currency  salary_in_usd  \
# 543             Data Engineer    99100             USD          99100
# 137               ML Engineer  8500000             JPY          77364
# ...

# %%
df.sample(n=100) #numero determinado de muestras
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 462         462       2022               MI              PT
# 78           78       2021               MI              CT
# 62           62       2020               EN              PT
# 403         403       2022               SE              FT
# 64           64       2020               SE              FT
# ..          ...        ...              ...             ...
# 226         226       2021               SE              FT
# 211         211       2021               MI              FT
# 395         395       2022               SE              FT
# 303         303       2022               SE              FT
# 132         132       2021               MI              FT
#
#                               job_title  salary salary_currency  \
# 462                       Data Engineer   50000             EUR
# 78                          ML Engineer  270000             USD
# ...

# %%
# agrupar datos determinados y bajo una medida
df.groupby("job_title").mean(numeric_only=True)
# Out:
#                                           Unnamed: 0    work_year  \
# job_title
# 3D Computer Vision Researcher              77.000000  2021.000000
# AI Scientist                              254.142857  2021.142857
# Analytics Engineer                        458.250000  2022.000000
# Applied Data Scientist                    351.600000  2021.600000
# Applied Machine Learning Scientist        321.000000  2021.500000
# BI Data Analyst                           106.333333  2020.833333
# Big Data Architect                        255.000000  2021.000000
# Big Data Engineer                         123.125000  2020.625000
# Business Data Analyst                     256.800000  2021.000000
# Cloud Data Engineer                       122.000000  2021.000000
# Computer Vision Engineer                  274.833333  2021.166667
# Computer Vision Software Engineer         235.666667  2021.333333
# Data Analyst                              362.010309  2021.680412
# ...

# %%
df.groupby("job_title").mean(numeric_only=True).count() #cuenta elementos de la agrupación
# Out:
# Unnamed: 0       50
# work_year        50
# salary           50
# salary_in_usd    50
# remote_ratio     50
# dtype: int64

# %%
df.groupby("job_title").agg({
    "salary_in_usd": ["max", "mean"]
})  #agrupar por una columan y determinadas medidas
# Out:
#                                          salary_in_usd
#                                                    max           mean
# job_title
# 3D Computer Vision Researcher                     5409    5409.000000
# AI Scientist                                    200000   66135.571429
# Analytics Engineer                              205300  175000.000000
# Applied Data Scientist                          380000  175655.000000
# Applied Machine Learning Scientist              423000  142068.750000
# BI Data Analyst                                 150000   74755.166667
# Big Data Architect                               99703   99703.000000
# Big Data Engineer                               114047   51974.000000
# Business Data Analyst                           135000   76691.200000
# Cloud Data Engineer                             160000  124647.000000
# Computer Vision Engineer                        125000   44419.333333
# ...

# %%
# agrupar datos determinados y bajo una medida
df.job_title.value_counts()
# Out:
# job_title
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Machine Learning Scientist                    8
# Big Data Engineer                             8
# Director of Data Science                      7
# AI Scientist                                  7
# Principal Data Scientist                      7
# Data Science Consultant                       7
# Data Analytics Manager                        7
# BI Data Analyst                               6
# Computer Vision Engineer                      6
# ML Engineer                                   6
# Lead Data Engineer                            6
# Applied Data Scientist                        5
# ...

# %%
df.shape #tamaño de data
# Out:
# (607, 12)

# %%
#elementos unicos de cada columna
df.nunique()
# Out:
# Unnamed: 0            607
# work_year               3
# experience_level        4
# employment_type         4
# job_title              50
# salary                272
# salary_currency        17
# salary_in_usd         369
# employee_residence     57
# remote_ratio            3
# company_location       50
# company_size            3
# dtype: int64

# %% [markdown]
# ### 1.4  Resumen: Análisis descriptivo inicial del dataset
#
# Antes de realizar cualquier proceso de limpieza o transformación, es importante hacer una lectura descriptiva de la base de datos. Esta etapa permite entender qué contiene el archivo, cómo están organizadas sus variables y qué primeros patrones pueden observarse sin modificar todavía la información.
#
# La base trabajada corresponde a un conjunto de datos sobre salarios en áreas relacionadas con ciencia de datos e inteligencia artificial. El dataset contiene **607 registros y 12 columnas**, por lo que se trata de una base de tamaño manejable para practicar exploración, consultas y análisis descriptivo con pandas.
#
# ## 1. Estructura general de la base
#
# Al revisar la estructura con funciones como `info()`, `head()`, `tail()`, `shape` y `columns`, se observa que la base combina variables numéricas y categóricas. Entre las variables numéricas se encuentran, por ejemplo, el año de trabajo, el salario reportado, el salario convertido a dólares y el porcentaje de trabajo remoto. Entre las variables categóricas aparecen el cargo, el nivel de experiencia, el tipo de contrato, la moneda, el país de residencia y el tamaño de la empresa.
#
# Esto muestra que la base permite hacer distintos tipos de análisis:
#
# - comparaciones entre categorías
# - resúmenes estadísticos de salarios
# - conteos de frecuencia
# - agrupaciones por cargo, nivel o país
#
# ## 2. Comportamiento general de los salarios
#
# Con `describe()` se obtiene un resumen estadístico de la columna `salary_in_usd`, que es una de las más importantes para el análisis porque ya estandariza los salarios en una sola moneda.
#
# A partir de esta descripción se observa que:
#
# - el salario promedio en USD es de **112.297,87**
# - la mediana es de **101.570**
# - el salario mínimo es de **2.859**
# - el salario máximo es de **600.000**
# - el 25 % de los registros está por debajo de **62.726**
# - el 75 % está por debajo de **150.000**
#
# Esto sugiere que los salarios presentan una dispersión amplia. Además, como la media es mayor que la mediana, puede inferirse que existen salarios altos que empujan el promedio hacia arriba. En otras palabras, la distribución no parece completamente equilibrada y probablemente haya valores altos que influyen bastante en el comportamiento general de la variable.
#
# ## 3. Distribución temporal de los registros
#
# Al contar los registros por año con `value_counts()` sobre `work_year`, se observa que la mayor parte de la información se concentra en los años más recientes del dataset:
#
# - **2020:** 72 registros
# - **2021:** 217 registros
# - **2022:** 318 registros
#
# Esto indica que la base tiene una fuerte concentración en 2021 y 2022. Por tanto, cualquier lectura general del dataset estará más influida por esos dos años que por 2020.
#
# ## 4. Cargos más frecuentes
#
# Al revisar la frecuencia de la variable `job_title`, se evidencia que algunos cargos aparecen con mucha más frecuencia que otros. Los más repetidos son:
#
# - **Data Scientist:** 143 registros
# - **Data Engineer:** 132 registros
# - **Data Analyst:** 97 registros
# - **Machine Learning Engineer:** 41 registros
# - **Research Scientist:** 16 registros
#
# Esto muestra que la base está especialmente cargada hacia perfiles muy representativos del sector de datos, en especial `Data Scientist`, `Data Engineer` y `Data Analyst`. Por tanto, los resultados globales del análisis estarán marcados en buena parte por esos cargos.
#
# ## 5. Nivel de experiencia predominante
#
# En la variable `experience_level`, los niveles aparecen con la siguiente frecuencia:
#
# - **SE:** 280 registros
# - **MI:** 213 registros
# - **EN:** 88 registros
# - **EX:** 26 registros
#
# Aquí se observa un predominio claro de perfiles **Senior/Expert (`SE`)**, seguido de niveles intermedios. Los perfiles de entrada y ejecutivos aparecen en menor proporción. Esto es importante porque ayuda a entender que la base no representa de forma equilibrada todos los niveles de experiencia.
#
# ## 6. Tipo de contratación
#
# La variable `employment_type` muestra una concentración muy fuerte en contratos de tiempo completo:
#
# - **FT:** 588 registros
# - **PT:** 10 registros
# - **CT:** 5 registros
# - **FL:** 4 registros
#
# Esto indica que la gran mayoría de registros corresponde a empleos de tiempo completo. Los contratos parciales, freelance o contractuales aparecen muy poco, por lo que no tienen el mismo peso dentro del dataset.
#
# ## 7. Trabajo remoto
#
# La variable `remote_ratio` permite observar el nivel de presencialidad o virtualidad de los empleos:
#
# - **0:** 127 registros
# - **50:** 99 registros
# - **100:** 381 registros
#
# Esto significa que predominan claramente los trabajos **completamente remotos**, seguidos por los presenciales y luego por los híbridos. Es una observación importante porque refleja una característica fuerte del mercado laboral representado en esta base.
#
# ## 8. Ubicación geográfica de empleados y empresas
#
# En cuanto a la residencia de los empleados y la localización de las empresas, la categoría más frecuente es **Estados Unidos**.
#
# ### Residencia del empleado
# - **US:** 332
# - **GB:** 44
# - **IN:** 30
# - **CA:** 29
# - **DE:** 25
#
# ### Ubicación de la empresa
# - **US:** 355
# - **GB:** 47
# - **CA:** 30
# - **DE:** 28
# - **IN:** 24
#
# Esto muestra que la base está fuertemente concentrada en el contexto estadounidense, tanto por lugar de residencia del trabajador como por ubicación de la empresa. En consecuencia, los resultados descriptivos globales reflejan principalmente la realidad de ese entorno.
#
# ## 9. Tamaño de empresa
#
# La variable `company_size` presenta esta distribución:
#
# - **M:** 326 registros
# - **L:** 198 registros
# - **S:** 83 registros
#
# Esto indica que predominan las empresas medianas, seguidas de las grandes. Las pequeñas tienen menor presencia en la base.
#
# ## 10. Agrupaciones y consultas descriptivas
#
# Además de la descripción general, el notebook ya empieza a profundizar con operaciones como `groupby()` y `agg()`, que permiten resumir la información por categorías. Por ejemplo, al agrupar por cargo y calcular medidas como promedio o máximo, se puede comparar cómo cambian los salarios según el tipo de empleo.
#
# Este tipo de consultas es importante porque permite pasar de una simple observación de la tabla a una lectura más analítica del dataset. Ya no se trata solo de ver filas, sino de encontrar patrones por grupos.
#
# ## 11. Primera conclusión descriptiva
#
# En conjunto, el análisis descriptivo muestra que se trata de una base organizada alrededor de empleos del sector de datos, con fuerte predominio de:
#
# - cargos como `Data Scientist`, `Data Engineer` y `Data Analyst`
# - contratos de tiempo completo
# - perfiles senior
# - empleos completamente remotos
# - empresas y trabajadores ubicados principalmente en Estados Unidos
#
# También se observa que los salarios presentan una dispersión considerable, con una media superior a la mediana, lo que sugiere la presencia de valores altos que elevan el promedio.

# %% [markdown]
# ### 1.5. Limpieza, normalización

# %% [markdown]
# Después de realizar el análisis descriptivo, el siguiente paso es revisar la calidad de la base y aplicar una limpieza básica. En este caso, el dataset `ds_salaries` no presenta una suciedad grave, pero sí conviene hacer una preparación ligera antes de continuar con análisis más profundos o con visualizaciones.
#
# #### ¿Qué limpieza tiene sentido en esta base?
#
# En este dataset, la limpieza más razonable es:
#
# - eliminar columnas irrelevantes, como `Unnamed: 0`, que parece ser solo un índice guardado
# - verificar si existen datos nulos
# - verificar si existen duplicados exactos
# - revisar que ciertas columnas tengan valores válidos
# - renombrar columnas para que sean más claras (si desea)
# - transformar algunas etiquetas abreviadas en nombres más comprensibles (si desea)
# - crear columnas derivadas que faciliten el  (cuando aplica)
#
# Es importante aclarar que esta base ya viene bastante ordenada. Por eso, aquí la limpieza no consiste en corregir grandes errores, sino en dejar el dataset más claro, más usable y más didáctico.

# %%
#revisar la estructura antes de limpiar
#Con esto confirmamos cuántas filas y columnas tenemos, cómo se llaman las variables y qué tipo de datos trae cada una.
print(df.shape)
print("-"*100)
print(df.columns)
print("-"*100)
print(df.info())
# Out:
# (607, 12)
# ----------------------------------------------------------------------------------------------------
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')
# ----------------------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
# ...

# %%
#eliminar columnas irrelevantes
# La columna Unnamed: 0 no representa una característica del fenómeno analizado.
#Parece ser un índice exportado junto con el archivo.
df = df.drop(columns=["Unnamed: 0"])
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
#revisar valores nulos
#Aunque en este dataset no se observan valores nulos, siempre conviene comprobarlo. Si el resultado es cero no se hace nada
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
#revisar duplicados exactos
# también conviene revisar si hay filas repetidas.
df.duplicated().sum()
# Out:
# np.int64(42)

# %% [markdown]
# Eso significa que hay 42 datos duplicados, 42 registros

# %%
#revisar si realmente son o no duplicados
df[df.duplicated()]
# Out:
#      work_year experience_level employment_type                  job_title  \
# 217       2021               MI              FT             Data Scientist
# 256       2021               MI              FT              Data Engineer
# 331       2022               SE              FT               Data Analyst
# 332       2022               SE              FT               Data Analyst
# 333       2022               SE              FT               Data Analyst
# 353       2022               SE              FT             Data Scientist
# 362       2022               SE              FT               Data Analyst
# 363       2022               SE              FT               Data Analyst
# 370       2022               SE              FT             Data Scientist
# 374       2022               MI              FT              ETL Developer
# 377       2022               SE              FT              Data Engineer
# ...

# %% [markdown]
# Ya revisamos y si son  efectivamente duplicados.

# %%
#eliminar duplicados
df = df.drop_duplicates()

# %%
df.duplicated().sum() #verificar de nuevo
# Out:
# np.int64(0)

# %%
#valores coinciden en la data, por ejemplo remote= 3 valores. Coincidan
df.nunique()
# Out:
# work_year               3
# experience_level        4
# employment_type         4
# job_title              50
# salary                272
# salary_currency        17
# salary_in_usd         369
# employee_residence     57
# remote_ratio            3
# company_location       50
# company_size            3
# dtype: int64

# %%
#todos los valores unicos por columna
for col in df.columns:
    print(f"\nColumna: {col}")
    print(df[col].unique())
# Out:
# Columna: work_year
# [2020 2021 2022]
#
# Columna: experience_level
# ['MI' 'SE' 'EN' 'EX']
#
# Columna: employment_type
# ['FT' 'CT' 'PT' 'FL']
#
# Columna: job_title
# ['Data Scientist' 'Machine Learning Scientist' 'Big Data Engineer'
#  'Product Data Analyst' 'Machine Learning Engineer' 'Data Analyst'
#  'Lead Data Scientist' 'Business Data Analyst' 'Lead Data Engineer'
#  'Lead Data Analyst' 'Data Engineer' 'Data Science Consultant'
#  'BI Data Analyst' 'Director of Data Science' 'Research Scientist'
#  'Machine Learning Manager' 'Data Engineering Manager'
#  'Machine Learning Infrastructure Engineer' 'ML Engineer' 'AI Scientist'
#  'Computer Vision Engineer' 'Principal Data Scientist'
#  'Data Science Manager' 'Head of Data' '3D Computer Vision Researcher'
#  'Data Analytics Engineer' 'Applied Data Scientist'
#  'Marketing Data Analyst' 'Cloud Data Engineer' 'Financial Data Analyst'
#  'Computer Vision Software Engineer' 'Director of Data Engineering'
# ...

# %%
# O todo de una vez
for col in df.columns:
    print(f"\nColumna: {col}")
    print(f"Cantidad de valores únicos: {df[col].nunique()}")
    print(df[col].unique())
# Out:
# Columna: work_year
# Cantidad de valores únicos: 3
# [2020 2021 2022]
#
# Columna: experience_level
# Cantidad de valores únicos: 4
# ['MI' 'SE' 'EN' 'EX']
#
# Columna: employment_type
# Cantidad de valores únicos: 4
# ['FT' 'CT' 'PT' 'FL']
#
# Columna: job_title
# Cantidad de valores únicos: 50
# ['Data Scientist' 'Machine Learning Scientist' 'Big Data Engineer'
#  'Product Data Analyst' 'Machine Learning Engineer' 'Data Analyst'
#  'Lead Data Scientist' 'Business Data Analyst' 'Lead Data Engineer'
#  'Lead Data Analyst' 'Data Engineer' 'Data Science Consultant'
#  'BI Data Analyst' 'Director of Data Science' 'Research Scientist'
#  'Machine Learning Manager' 'Data Engineering Manager'
#  'Machine Learning Infrastructure Engineer' 'ML Engineer' 'AI Scientist'
#  'Computer Vision Engineer' 'Principal Data Scientist'
#  'Data Science Manager' 'Head of Data' '3D Computer Vision Researcher'
#  'Data Analytics Engineer' 'Applied Data Scientist'
# ...

# %%
#revisar tipos de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 565 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           565 non-null    int64
#  1   experience_level    565 non-null    object
#  2   employment_type     565 non-null    object
#  3   job_title           565 non-null    object
#  4   salary              565 non-null    int64
#  5   salary_currency     565 non-null    object
#  6   salary_in_usd       565 non-null    int64
#  7   employee_residence  565 non-null    object
#  8   remote_ratio        565 non-null    int64
#  9   company_location    565 non-null    object
#  10  company_size        565 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 53.0+ KB

# %%
#  decidir qué hacer con columnas parecidas (salary es similar a salary_in_usd), salary in usd es mas global, asi que tambien se puede elimianr salary_current
df = df.drop(columns=["salary", "salary_currency"])

# %%
#revisar cómo quedó la base después de la limpieza
print(df.shape)
print("-"*100)
print(df.columns)
print("-"*100)
print(df.info())
# Out:
# (565, 9)
# ----------------------------------------------------------------------------------------------------
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_in_usd', 'employee_residence', 'remote_ratio',
#        'company_location', 'company_size'],
#       dtype='object')
# ----------------------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Index: 565 entries, 0 to 606
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           565 non-null    int64
#  1   experience_level    565 non-null    object
#  2   employment_type     565 non-null    object
#  3   job_title           565 non-null    object
#  4   salary_in_usd       565 non-null    int64
#  5   employee_residence  565 non-null    object
#  6   remote_ratio        565 non-null    int64
# ...

# %%
#cambiar nombres de columnas (solo si deseo)
'''df = df.rename(columns={
    "work_year": "anio_trabajo",
    "experience_level": "nivel_experiencia",
    "employment_type": "tipo_contrato",
    "job_title": "cargo",
    "salary_in_usd": "salario_usd",
    "employee_residence": "residencia_empleado",
    "remote_ratio": "porcentaje_remoto",
    "company_location": "ubicacion_empresa",
    "company_size": "tamano_empresa"
})
'''
# Out:
# 'df = df.rename(columns={\n    "work_year": "anio_trabajo",\n    "experience_level": "nivel_experiencia",\n    "employment_type": "tipo_contrato",\n    "job_title": "cargo",\n    "salary_in_usd": "salario_usd",\n    "employee_residence": "residencia_empleado",\n    "remote_ratio": "porcentaje_remoto",\n    "company_location": "ubicacion_empresa",\n    "company_size": "tamano_empresa"\n})\n'

# %%
#guardar data limpia
# guardar la base limpia
df.to_csv("/content/drive/MyDrive/bootcamp_ia_2026-1/ds_salaries_limpia.csv", index=False)

# %% [markdown]
# #### Análisis breve de la limpieza realizada
#
# En esta etapa se realizó una limpieza básica del dataset con el objetivo de dejar la base más consistente y adecuada para el análisis. En primer lugar, se revisaron los tipos de datos con `info()` para comprobar que las variables numéricas y categóricas estuvieran correctamente interpretadas. En este caso, no fue necesario hacer conversiones importantes, ya que los formatos eran coherentes con el contenido de cada columna.
#
# También se verificó la presencia de valores nulos con `isnull().sum()`. Esta revisión permitió confirmar si existían datos faltantes que pudieran afectar conteos, agrupaciones o medidas descriptivas. Además, se revisaron duplicados con `duplicated().sum()`, encontrando registros repetidos que luego fueron eliminados para evitar que inflaran frecuencias, promedios u otras conclusiones.
#
# Otro paso importante fue retirar columnas que no aportaban valor al análisis, como aquellas que funcionaban solo como índice o que no estaban relacionadas con la pregunta de estudio. Esto ayudó a dejar una base más limpia y enfocada en las variables realmente útiles.
#
# En esta limpieza no se cambiaron los nombres de las columnas, ya que no era necesario hacerlo: el dataset estaba en inglés y mantener la nomenclatura original ayudaba a conservar coherencia con la fuente de datos y con el notebook.
#
# En conclusión, la limpieza aplicada no fue una transformación profunda de la base, pero sí permitió mejorar su calidad y dejarla lista para continuar con el análisis descriptivo y exploratorio de una forma más confiable.

# %% [markdown]
# ## 2. Visualización de datos con Matplolib

# %% [markdown]
# ### 2.1. Gráfico de barras

# %%
#abrir data
df = pd.read_csv("/content/drive/MyDrive/bootcamp_ia_2026-1/ds_salaries_limpia.csv")

# %%
#las primeras 10 empleos mas comunes
top10_job_title = df['job_title'].value_counts()[:10]

# %%
top10_job_title
# Out:
# job_title
# Data Scientist                130
# Data Engineer                 121
# Data Analyst                   82
# Machine Learning Engineer      39
# Research Scientist             16
# Data Science Manager           12
# Data Architect                 11
# Machine Learning Scientist      8
# Big Data Engineer               8
# Director of Data Science        7
# Name: count, dtype: int64

# %% [markdown]
# **Lineas de codificación**
# * px.bar(...): Crea un gráfico de barras.
# * x=top10_job_title.index: Usa los títulos de trabajo (índices de la serie) como el eje X.
# * y=top10_job_title.values: Usa la cantidad de veces que aparecen los títulos como eje Y.
# * color=top10_job_title.index: Asigna diferentes colores a cada categoría (título de trabajo).
# * color_discrete_sequence=px.colors.sequential.PuBuGn: Usa una paleta de colores predefinida (PuBuGn).
# * text=top10_job_title.values: Muestra los valores sobre las barras.
# * title='2.1.2. Top 10 Job Titles': Agrega un título al gráfico.
# * template='plotly_dark': Usa un tema oscuro para el diseño.

# %%
fig = px.bar(y=top10_job_title.values,
             x=top10_job_title.index,
             color = top10_job_title.index,
             color_discrete_sequence=px.colors.sequential.PuBuGn,
             text=top10_job_title.values,
             title= 'Top 10 Job Titles',
             template= 'plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# El método update_layout() se usa para modificar el diseño del gráfico. Aquí está lo que hace cada argumento:
#
# * xaxis_title="Job Titles" : Cambia el título del eje X a "Job Titles" (Títulos de Trabajo).
# y Este eje representa las categorías (diferentes títulos de trabajo).
#
# *yaxis_title="count" : Cambia el título del eje Y a "count" (Cantidad).
# Este eje muestra la frecuencia de cada título de trabajo en los datos.
#
# * font=dict(size=17, family="Franklin Gothic") Ajusta el tamaño y la fuente del texto en el gráfico.
# size=17: Aumenta el tamaño del texto a 17 puntos.
# family="Franklin Gothic": Usa la fuente "Franklin Gothic" para los textos.

# %%
fig.update_layout(
    xaxis_title="Job Titles",
    yaxis_title="count",
    font = dict(size=17,family="Franklin Gothic"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 2.2. Gráfico de tortas

# %%
# Contar cuántos registros hay por año
conteo_años = df["work_year"].value_counts()
print(conteo_años)

# Crear el gráfico de torta
plt.figure(figsize=(8,8))
plt.pie(conteo_años, labels=conteo_años.index, autopct="%1.1f%%", colors=plt.cm.Paired.colors)

# Título y mostrar gráfico
plt.title("Distribución de registros por Año")
plt.show()
# Out:
# work_year
# 2022    278
# 2021    215
# 2020     72
# Name: count, dtype: int64

# %% [markdown]
# ### 2.3. Gráfico de líneas o dispersión

# %% [markdown]
# vamos a construir un digrama de lineas por cada variable cuantitativa, sirve para ver el comportramiento de una variable en el tiempo

# %%
#agrupamos salario por mean tras cada año
salario_anual = df.groupby("work_year")["salary_in_usd"].mean().reset_index()

plt.figure(figsize=(8,5))
plt.plot(salario_anual["work_year"], salario_anual["salary_in_usd"], marker="o")
plt.title("Salario promedio por año")
plt.xlabel("Año")
plt.ylabel("Salario en USD")
plt.grid(True)
plt.show()

# %% [markdown]
# ### 2.4. Distribución normal

# %%
#seleccionamos solo tipo de datos numericos
df_cuant= df.select_dtypes(include=['int64', 'float64'])
df_cuant
# Out:
#      work_year  salary_in_usd  remote_ratio
# 0         2020          79833             0
# 1         2020         260000             0
# 2         2020         109024            50
# 3         2020          20000             0
# 4         2020         150000            50
# ..         ...            ...           ...
# 560       2022         154000           100
# 561       2022         126000           100
# 562       2022         129000             0
# 563       2022         150000           100
# 564       2022         200000           100
#
# [565 rows x 3 columns]

# %%
# Graficar cada variable numérica con su campana de Gauss
for columna in df_cuant.columns:
    plt.figure(figsize=(8, 5))  # Nueva figura para cada variable

    # Histograma con densidad
    sns.histplot(df_cuant[columna], kde=True, bins=20, stat="density", color="blue", label="Datos")

    # Ajuste de la curva normal teórica
    media = df_cuant[columna].mean()
    desviacion = df_cuant[columna].std()
    x = np.linspace(df_cuant[columna].min(), df_cuant[columna].max(), 100) #linea de ahuste de la cuerva
    y = norm.pdf(x, media, desviacion)
    plt.plot(x, y, color="red", label="Campana de Gauss")

    # Personalización del gráfico
    plt.title(f"Distribución de {columna}")
    plt.xlabel(columna)
    plt.ylabel("Densidad")
    plt.legend()
    plt.grid(True)

    plt.show()  # Muestra cada gráfico individualmente

# %%
from scipy.stats import norm, probplot, shapiro



# Variable a analizar
columna = "salary_in_usd"

# Eliminar nulos por si existen
datos = df[columna].dropna()

# -----------------------------
# 1. Histograma + curva normal
# -----------------------------
plt.figure(figsize=(8,5))

plt.hist(datos, bins=20, density=True, edgecolor="black", alpha=0.7)

media = datos.mean()
desviacion = datos.std()

x = np.linspace(datos.min(), datos.max(), 200)
y = norm.pdf(x, media, desviacion)

plt.plot(x, y, linewidth=2, label="Campana de Gauss")
plt.title(f"Histograma y curva normal - {columna}")
plt.xlabel(columna)
plt.ylabel("Densidad")
plt.legend()
plt.grid(True)
plt.show()

# -----------------------------
# 2. QQ-plot
# -----------------------------
plt.figure(figsize=(6,6))
probplot(datos, dist="norm", plot=plt)
plt.title(f"QQ-plot - {columna}")
plt.grid(True)
plt.show()

# -----------------------------
# 3. Boxplot
# -----------------------------
plt.figure(figsize=(8,2.5))
plt.boxplot(datos, vert=False)
plt.title(f"Boxplot - {columna}")
plt.xlabel(columna)
plt.grid(True)
plt.show()

# -----------------------------
# 4. Prueba de Shapiro-Wilk
# -----------------------------
# Si hay demasiados datos, se toma una muestra
muestra = datos.sample(min(5000, len(datos)), random_state=42)

estadistico, p_valor = shapiro(muestra)

print("Prueba de Shapiro-Wilk")
print("Estadístico:", estadistico)
print("p-valor:", p_valor)

if p_valor > 0.05:
    print("No hay evidencia fuerte para rechazar la normalidad.")
else:
    print("Los datos probablemente no siguen una distribución normal.")
# Out:
# Prueba de Shapiro-Wilk
# Estadístico: 0.8906818628817311
# p-valor: 1.3630672539081726e-19
# Los datos probablemente no siguen una distribución normal.

# %% [markdown]
# ### 2.5. Matriz de correlacion

# %% [markdown]
# la correlacción entre los datos, sirve para revisar la relacion de los datos

# %%
correlacion = df_cuant.corr() #hallar valor de datos relacionados
correlacion
# Out:
#                work_year  salary_in_usd  remote_ratio
# work_year       1.000000       0.159326      0.058879
# salary_in_usd   0.159326       1.000000      0.122849
# remote_ratio    0.058879       0.122849      1.000000

# %%
# graficad
correlacion = df_cuant.corr()
# 🔹 Crear el mapa de calor
plt.figure(figsize=(10, 6))  # Ajustar tamaño de la figura
sns.heatmap(correlacion, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

# 🔹 Título del gráfico
plt.title("Matriz de Correlación")

# 🔹 Mostrar el gráfico
plt.show()

# %% [markdown]
# ### 2.6. Diagrama de cajas

# %%
# 🔹 Crear un boxplot para todas las columnas numéricas
plt.figure(figsize=(12,6))  # Tamaño del gráfico
sns.boxplot(df_cuant)

# 🔹 Mejorar visualización
plt.xticks(rotation=45)  # Rotar nombres de variables
plt.title("Diagramas de caja de todas las variables numéricas")

# 🔹 Mostrar gráfico
plt.show()

# %%
for i in range(0, df_cuant.shape[1]):
    plt.figure(figsize=(8,6))  # Tamaño de cada gráfico
    sns.boxplot(x=df_cuant.iloc[:, i])
    plt.title(f"Distribución de {df_cuant.columns[i]}")  # Título con el nombre de la variable
    plt.show()

# %% [markdown]
# ### 2.7. Diagrama de nulos

# %%
#valores nulos en toda la data
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cmap="viridis", cbar=False, yticklabels=False)
plt.title("Mapa de calor de valores nulos")
plt.show()

# %%
# nulos en  df_cuant
plt.figure(figsize=(12,6))
sns.heatmap(df_cuant.isnull(), cmap="viridis", cbar=False, yticklabels=False)
plt.title("Mapa de calor de valores nulos")
plt.show()
